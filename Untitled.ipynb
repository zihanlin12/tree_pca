# %%
import numpy as np
data= np.load('C:/Users/zihanlin/Desktop/File/Research/npz_data/processed_data.npz')
data= data['data']

# %%
print (np.sum(np.isnan(data)))
print (data.shape)
# Out:
# 0
# (359, 505, 9)

# %%
import pandas as pd
U= pd.read_csv('U.csv')
U= pd.DataFrame.as_matrix(U)

# %%
import numpy as np
T,M= U.shape
Sigma= 1.0/T*U.T.dot(U)
print (np.max(abs(U)))
print (Sigma[1,1]*100000000)
print (np.linalg.matrix_rank(Sigma))
# Out:
# 58.6691680714
# 993357624.385
# 355

# %%
import numpy as np
import os

current_dir= os.getcwd()
current_dir= current_dir+'./npz_data/Np_processed.npz'
data= np.load(current_dir)
data= data['data']

# %%
print (np.sum(data==-99.99))
print (data.shape)
# Out:
# 0
# (359L, 2448L, 42L)

# %%
print (data)
# Out:
# [[[  4.90820000e+04  -3.02631587e-01   5.01426000e+04 ...,  -2.73296473e-01
#      7.45098039e-01   3.49159971e-02]
#   [  6.25000000e+04   2.09876537e-01   5.01426000e+04 ...,   2.48903448e+01
#      4.21875000e-01   2.60798944e-01]
#   [  1.01530000e+04  -7.52688200e-02   5.01426000e+04 ...,  -6.35713653e-01
#      6.15894040e-01   3.68983225e-01]
#   ...,
#   [  6.81450000e+04   1.66666672e-01   5.01426000e+04 ...,  -2.06176621e-01
#      5.00000000e-01   0.00000000e+00]
#   [  3.88930000e+04  -1.20754719e-01   5.01426000e+04 ...,   2.60852559e+00
#      8.49358974e-01   6.98785043e-01]
#   [  3.07600000e+04  -5.26315790e-02   5.01426000e+04 ...,   2.31677571e-01
#      8.50746269e-01   3.49979944e-02]]
#
#  [[  1.91660000e+04   1.00257069e-01   5.03919750e+04 ...,  -8.24265086e-01
#      9.97435897e-01   2.18123968e-01]
#   [  1.27230000e+04  -2.63157904e-01   5.03919750e+04 ...,  -3.90791953e-01
#      1.86274510e-01   4.79192938e-01]
# ...
